# %% [markdown]
# ## Ranking de cada tipo de jogo em determinadas plataformas
# - O indice de cada linha representa cada plataforma.
# - As celulas representam as avaliacoes daquele gênero.
# - E essas variam de 0 (Desastre) a 10 (Obra-prima).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

jogos = 'ign_scores.csv'
df = pd.read_csv(jogos, index_col='Platform')

# %%
#dataset
df.head()
# Out:
#                     Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast         6.882857           7.511111   6.281818  8.200000
# Game Boy Advance  6.373077           7.507692   6.057143  6.226316
# Game Boy Color    6.272727           8.166667   5.307692  4.500000
# GameCube          6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS      6.670833           7.481818   7.414286  6.614286
#
#                   Platformer    Puzzle       RPG    Racing   Shooter  \
# Platform
# Dreamcast           8.340000  8.088889  7.700000  7.042500  7.616667
# Game Boy Advance    6.970588  6.532143  7.542857  6.657143  6.444444
# Game Boy Color      6.352941  6.583333  7.285714  5.897436  4.500000
# GameCube            6.665714  6.133333  7.890909  6.852632  6.981818
# Nintendo 3DS        7.503448  8.000000  7.719231  6.900000  7.033333
#
#                   Simulation    Sports  Strategy
# Platform
# Dreamcast           7.628571  7.272222  6.433333
# ...

# %% [markdown]
# ### Avaliacao dos Jogos de Esporte em cada Plataforma

# %%
plt.figure(figsize=(10,10))
plt.title('Avaliacao Media dos Jogos de Esportes, por Plataforma')
sns.barplot(x=df['Sports'], y=df.index)
plt.xlabel('Avaliacao media')
plt.ylabel('Plataformas')
plt.show()

# %% [markdown]
# ### Avaliacao Media de cada jogo, por plataforma

# %%
plt.figure(figsize=(10,7))
plt.title('Avaaliaco Media de cada jogo, por plataforma')
sns.heatmap(data=df, annot=True)
plt.xlabel('Tipo de Jogo')
plt.ylabel('Plataformas')
plt.show()

# %% [markdown]
# ### Conclusões
#
# - Diferença por gênero: certos gêneros (como Platformer e RPG) costumam receber notas mais altas em algumas plataformas.
#
# - Diferença por plataforma: algumas plataformas se destacam em gêneros específicos. Por exemplo:
#     - Dreamcast teve notas bem altas em Platformer e Puzzle.
#     - Nintendo 3DS foi forte em Adventure e Platformer.
#     - GameCube se destacou em Simulation e RPG.
#
# - Esportes: o gráfico evidencia que algumas plataformas se destacaram nesse gênero, alcançando notas médias mais altas e consistentes. Isso sugere que consoles com maior variedade de títulos esportivos ou com foco nesse público tendem a receber melhores avaliações nesse tipo de jogo.
#
# De um modo geral (heatmap): dá para perceber que não existe “a melhor plataforma em tudo”, mas sim que cada uma tem pontos fortes em determinados gêneros.
